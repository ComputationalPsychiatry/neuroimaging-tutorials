# %%
# http://nilearn.github.io/auto_examples/plot_nilearn_101.html#sphx-glr-auto-examples-plot-nilearn-101-py

from nilearn import plotting

plotting.plot_img("C:/Users/Ege/Desktop/Nilearn/sub001/anatomy/highres001.nii")

plotting.show()

# %%
from nilearn import image

# %%
smooth_anat_img = image.smooth_img("C:/Users/Ege/Desktop/Nilearn/sub001/anatomy/highres001.nii", fwhm=3)

# %%
print(smooth_anat_img)
# Out:
# <class 'nibabel.nifti1.Nifti1Image'>
# data shape (176L, 256L, 256L)
# affine:
# [[  -1.           -0.           -0.            2.16867828]
#  [  -0.            1.           -0.         -128.94578552]
#  [   0.            0.            1.         -127.5       ]
#  [   0.            0.            0.            1.        ]]
# metadata:
# <class 'nibabel.nifti1.Nifti1Header'> object, endian='<'
# sizeof_hdr      : 348
# data_type       :
# db_name         :
# extents         : 0
# session_error   : 0
# regular         : r
# dim_info        : 0
# dim             : [  3 176 256 256   1   1   1   1]
# intent_p1       : 0.0
# intent_p2       : 0.0
# intent_p3       : 0.0
# intent_code     : none
# datatype        : int16
# bitpix          : 16
# slice_start     : 0
# pixdim          : [-1.  1.  1.  1.  0.  0.  0.  0.]
# vox_offset      : 0.0
# scl_slope       : nan
# scl_inter       : nan
# slice_end       : 0
# slice_code      : unknown
# xyzt_units      : 2
# cal_max         : 0.0
# ...

# %%
plotting.plot_img(smooth_anat_img)
plotting.show()

# %%
more_smooth_anat_img = image.smooth_img(smooth_anat_img, fwhm=3)
plotting.plot_img(more_smooth_anat_img)
plotting.show()
