# %%
import nibabel as nib
anat = nib.load("C:/Users/Ege/Desktop/Nilearn/sub001/anatomy/highres001.nii.gz")
anat.shape
# Out:
# (176, 256, 256)

# %%
print(anat.affine)
# Out:
# [[  -1.           -0.           -0.            2.16867828]
#  [  -0.            1.           -0.         -128.94578552]
#  [   0.            0.            1.         -127.5       ]
#  [   0.            0.            0.            1.        ]]

# %%
print(anat.header)
# Out:
# <class 'nibabel.nifti1.Nifti1Header'> object, endian='<'
# sizeof_hdr      : 348
# data_type       :
# db_name         :
# extents         : 0
# session_error   : 0
# regular         : r
# dim_info        : 0
# dim             : [  3 176 256 256   1   1   1   1]
# intent_p1       : 0.0
# intent_p2       : 0.0
# intent_p3       : 0.0
# intent_code     : none
# datatype        : int16
# bitpix          : 16
# slice_start     : 0
# pixdim          : [-1.  1.  1.  1.  0.  0.  0.  0.]
# vox_offset      : 0.0
# scl_slope       : nan
# scl_inter       : nan
# slice_end       : 0
# slice_code      : unknown
# xyzt_units      : 2
# cal_max         : 0.0
# cal_min         : 0.0
# slice_duration  : 0.0
# toffset         : 0.0
# glmax           : 0
# glmin           : 0
# descrip         :
# aux_file        :
# qform_code      : scanner
# sform_code      : scanner
# quatern_b       : -0.0
# quatern_c       : 1.0
# quatern_d       : 0.0
# qoffset_x       : 2.16867828369
# ...

# %%
anat.get_data()
# Out:
# array([[[ 5, 11, 11, ...,  4, 10,  0],
#         [ 1,  3,  5, ..., 19,  4,  0],
#         [18, 14,  3, ..., 13,  8,  0],
#         ...,
#         [ 2, 10,  6, ..., 14,  7,  0],
#         [16,  5,  1, ..., 10,  7,  0],
#         [ 0,  0,  0, ...,  0,  0,  0]],
#
#        [[12,  8,  0, ...,  6,  6,  0],
#         [11,  6, 15, ..., 14,  5,  0],
#         [11,  5,  9, ..., 12,  2,  0],
#         ...,
#         [15, 16, 11, ...,  8,  6,  0],
#         [15, 20, 10, ..., 31, 11,  0],
#         [ 0,  0,  0, ...,  0,  0,  0]],
#
#        [[14,  7, 13, ..., 18, 23,  0],
#         [11, 19,  7, ...,  9,  1,  0],
#         [11, 15, 13, ..., 10, 10,  0],
#         ...,
#         [ 6,  8,  1, ...,  8, 18,  0],
#         [ 6, 14, 11, ..., 20,  9,  0],
#         [ 0,  0,  0, ...,  0,  0,  0]],
#
#        ...,
#        [[16,  7, 11, ..., 10,  6,  0],
#         [14, 12,  9, ..., 22,  9,  0],
#         [18, 12,  7, ..., 16,  5,  0],
#         ...,
#         [11, 14,  3, ..., 17, 21,  0],
# ...

# %%
func = nib.load("C:/Users/Ege/Desktop/Nilearn/sub001/BOLD/task001_run001/bold.nii.gz")
func.shape
# Out:
# (64, 64, 40, 146)

# %%
print(func.affine)
# Out:
# [[  3.           0.           0.         -95.22289276]
#  [  0.           3.           0.         -90.16265106]
#  [  0.           0.           4.         -78.        ]
#  [  0.           0.           0.           1.        ]]

# %%
print(func.header)
# Out:
# <class 'nibabel.nifti1.Nifti1Header'> object, endian='<'
# sizeof_hdr      : 348
# data_type       :
# db_name         :
# extents         : 0
# session_error   : 0
# regular         : r
# dim_info        : 0
# dim             : [  4  64  64  40 146   1   1   1]
# intent_p1       : 0.0
# intent_p2       : 0.0
# intent_p3       : 0.0
# intent_code     : none
# datatype        : int16
# bitpix          : 16
# slice_start     : 0
# pixdim          : [  1.00000000e+00   3.00000000e+00   3.00000000e+00   4.00000000e+00
#    2.00000000e+03   0.00000000e+00   0.00000000e+00   0.00000000e+00]
# vox_offset      : 0.0
# scl_slope       : nan
# scl_inter       : nan
# slice_end       : 0
# slice_code      : unknown
# xyzt_units      : 10
# cal_max         : 0.0
# cal_min         : 0.0
# slice_duration  : 0.0
# toffset         : 0.0
# glmax           : 0
# glmin           : 0
# descrip         : FSL4.0
# aux_file        :
# qform_code      : scanner
# sform_code      : scanner
# ...

# %%
func.get_data()
# Out:
# array([[[[ 4, 10, 13, ..., 19,  9,  6],
#          [22, 13, 28, ..., 16, 21, 14],
#          [14,  8,  5, ..., 11, 10, 15],
#          ...,
#          [20,  6,  6, ...,  6, 12,  9],
#          [15,  8,  1, ..., 10,  6, 10],
#          [15,  6, 17, ..., 10, 13,  8]],
#
#         [[14,  8, 29, ..., 12,  8,  6],
#          [21, 15, 26, ...,  4, 20,  6],
#          [25,  8,  6, ...,  8,  5, 14],
#          ...,
#          [17,  5, 13, ...,  4, 11,  8],
#          [ 5, 14,  7, ..., 11, 15, 11],
#          [19,  7, 15, ..., 18, 12, 20]],
#
#         [[ 2, 10,  8, ..., 19,  9,  6],
#          [17, 13, 22, ..., 23, 20, 21],
#          [ 2, 18,  6, ..., 12, 18, 16],
#          ...,
#          [19,  5,  9, ..., 13, 11,  9],
#          [17, 11,  5, ...,  7,  4, 10],
#          [12,  8, 20, ...,  6, 10,  1]],
#
#         ...,
#         [[10,  7, 10, ...,  8, 15,  6],
#          [17, 13, 16, ...,  0, 17, 12],
#          [ 1, 13, 11, ..., 22, 31,  8],
#          ...,
# ...
