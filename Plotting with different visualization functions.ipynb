# %%
# http://nilearn.github.io/auto_examples/01_plotting/plot_demo_plotting.html#sphx-glr-auto-examples-01-plotting-plot-demo-plotting-py

from nilearn import plotting

plotting.plot_img("C:/Users/Ege/Desktop/Nilearn/sub001/anatomy/highres001.nii")
plotting.show()

# %%
plotting.plot_img("C:/Users/Ege/Desktop/Nilearn/sub001/anatomy/highres001_brain.nii")
plotting.show()

# %%
from nilearn import plotting
plotting.plot_glass_brain("C:\Users/Ege/Desktop/Nilearn/sub001/anatomy/highres001.nii")
plotting.show()

# %%
from nilearn import plotting
plotting.plot_glass_brain("C:\Users/Ege/Desktop/Nilearn/sub001/anatomy/highres001_brain.nii")
plotting.show()

# %%
plotting.plot_anat("C:\Users/Ege/Desktop/Nilearn/sub001/anatomy/highres001.nii")
plotting.show()

# %%
plotting.plot_anat("C:\Users/Ege/Desktop/Nilearn/sub001/anatomy/highres001_brain.nii")
plotting.show()

# %%
from nilearn.image.image import mean_img

mean_sample = mean_img("C:\Users/Ege/Desktop/Nilearn/sub001/anatomy/highres001.nii")

from nilearn import plotting
plotting.plot_epi(mean_sample)
plotting.show()

# %%
from nilearn.image.image import mean_img

mean_sample = mean_img("C:\Users/Ege/Desktop/Nilearn/sub001/anatomy/highres001_brain.nii")

from nilearn import plotting
plotting.plot_epi(mean_sample)
plotting.show()

# %%
from nilearn import plotting
plotting.plot_stat_map("C:\Users/Ege/Desktop/Nilearn/sub001/anatomy/highres001_brain.nii")
plotting.show()
